# %% [markdown]
# ## **Exploratory data analysis** ##

# %% [markdown]
# **Importing the libraries for the analysis**

# %%
import pandas as pd
import os
import openpyxl as pyxl
import matplotlib as plt
import seaborn as sns

# %%
# Loading our dataset
sales = pd.read_csv("sales_data.xls")

# %%
# Checking the data type for the columns
sales.dtypes
# Out:
# customer_id        object
# device_id          object
# item_id             int64
# line_item_id        int64
# order_id           object
# event_id            int64
# event_timestamp    object
# quantity            int64
# currency           object
# checked_out_at     object
# status             object
# location           object
# dtype: object

# %%
# Checking for duplicate data
sales.duplicated().sum
sales
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
# Checking for missing data
sales.isnull().sum
sales
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
# Checking for the size of the dataset
sales.shape
# Out:
# (578320, 12)

# %%
# Indexing the dataset
sales1 = pd.DataFrame(sales, columns=sales.columns, index=range(1, len(sales)+1))
sales1
# Out:
#                                  customer_id  \
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# 5       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578320                                   NaN
#
#                                    device_id  item_id  line_item_id  \
# 1       33b485de-7338-4997-b1d0-b988ba17b245      5.0        3202.0
# 2       33b485de-7338-4997-b1d0-b988ba17b245      9.0        3203.0
# 3       33b485de-7338-4997-b1d0-b988ba17b245     12.0        3204.0
# 4       33b485de-7338-4997-b1d0-b988ba17b245      6.0        3205.0
# 5       33b485de-7338-4997-b1d0-b988ba17b245     11.0        3206.0
# ...

# %%
# Using loc to print the index of these columns
sales1.loc[0:7, ["customer_id", "device_id", "item_id"]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 5  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 7  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 1      5.0
# 2      9.0
# 3     12.0
# 4      6.0
# 5     11.0
# 6      4.0
# 7      5.0

# %%
# Setting the index of the dataset using the column "locations"
sales.set_index("location", inplace=True)
sales
# Out:
#                                            customer_id  \
# location
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Saint Helena      33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena      33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# ...

# %%
# Display the first five elements in the dataset
sales.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
# Displaying the location of the data set as the index
sales.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578320)

# %%
# Displaying the list of unique locations with customers
unique_locations_index = sales.index.unique().sort_values()
print(f"These are the unique customer locations:\n{unique_locations_index}")
# Out:
# These are the unique customer locations:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica (the territory South of 60 deg S)',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=243)

# %%
# Checking the number of customer locations that are unique
unique_locations = sales.index.nunique()
print(f"Total number of unique locations is {unique_locations}")
# Out:
# Total number of unique locations is 243

# %%
# To check the top 10 locations with the most sales
top_ten_sales = sales.index.value_counts().head(10)
print(f"These are the top ten locations with the most sales:\n{top_ten_sales}")
# Out:
# These are the top ten locations with the most sales:
# location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of top ten locations with most sales using barchart pandas`

# %%
# A barchart of the top ten locations with most sales
top_ten_sales = sales.index.value_counts().head(10).plot(kind= 'bar',color='black', ylabel= "Purchases",title='Top ten locations with most sales')
top_ten_sales
# Out:
# <Axes: title={'center': 'Top ten locations with most sales'}, xlabel='location', ylabel='Purchases'>

# %%
# Checking the last ten locations with the least sales
ten_least_sales = sales.index.value_counts().tail(10)
print(f"These are the least ten locations with the lowest sales:\n{ten_least_sales}")
# Out:
# These are the least ten locations with the lowest sales:
# location
# Greece                     1214
# Saint Kitts and Nevis      1201
# Honduras                   1195
# Cocos (Keeling) Islands    1168
# Taiwan                     1122
# Chad                       1082
# Malaysia                   1037
# Austria                     921
# Italy                       783
# Uruguay                     734
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of last ten locations with the least sales using barchart in pandas`

# %%
# A barchart of the ten locations with least sales
ten_least_sales = sales.index.value_counts().tail(10).plot(kind='bar', ylabel= 'Purchases', color='red', title='Ten Countries with the least sales')
ten_least_sales
# Out:
# <Axes: title={'center': 'Ten Countries with the least sales'}, xlabel='location', ylabel='Purchases'>

# %%
# Checking the top 50 locations with the highest number of purchase
top_fifty_sales = sales.index.value_counts().head(50)
print(f"These are the top fifty locations with the most sales:\n{top_fifty_sales}")
# Out:
# These are the top fifty locations with the most sales:
# location
# Korea                          6997
# Argentina                      4507
# Mauritius                      4414
# Jersey                         4130
# Panama                         3936
# French Guiana                  3851
# Guernsey                       3804
# Guatemala                      3731
# Albania                        3721
# Philippines                    3675
# Mali                           3670
# Congo                          3642
# Finland                        3615
# Cape Verde                     3509
# Christmas Island               3471
# China                          3429
# France                         3425
# French Southern Territories    3421
# Poland                         3355
# Cyprus                         3345
# Switzerland                    3342
# British Virgin Islands         3329
# Bosnia and Herzegovina         3309
# Niger                          3295
# ...

# %% [markdown]
# `Data visualization of top fifty locations with most sales using barchart in pandas`

# %%
# A chart of top 50 locations with the highest number of purchase
top_fifty_sales = sales.index.value_counts().head(50).plot(kind='bar',ylabel= 'Purchases', figsize = (20,20), color='purple', title="Top fifty locations with most sales")
top_ten_sales
# Out:
# <Axes: title={'center': 'Top ten locations with most sales'}, xlabel='location', ylabel='Purchases'>

# %% [markdown]
# `Data visualization of least fifty locations with low sales using barchart in pandas`

# %%
# Checking the least fifty countries with low sales
fifty_least_sales = sales.index.value_counts().tail(50)
print(f"These are the least fifty locations with lowest sales:\n{fifty_least_sales}")
# Out:
# These are the least fifty locations with lowest sales:
# location
# Falkland Islands (Malvinas)                     1743
# Angola                                          1742
# Ghana                                           1735
# Bulgaria                                        1733
# Benin                                           1727
# Denmark                                         1720
# India                                           1712
# Aruba                                           1712
# French Polynesia                                1695
# Ireland                                         1689
# Burkina Faso                                    1683
# American Samoa                                  1682
# Antarctica (the territory South of 60 deg S)    1674
# Micronesia                                      1666
# Spain                                           1665
# Sudan                                           1662
# ...

# %%
# A chart of the least 50 locations with the lowest number of purchase
fifty_least_sales = sales.index.value_counts().tail(50).plot(kind='bar', figsize = (20,20), ylabel= 'Purchases', color='red', title='Least Fifty locations with low sales')
fifty_least_sales
# Out:
# <Axes: title={'center': 'Least Fifty locations with low sales'}, xlabel='location', ylabel='Purchases'>

# %%
# Checking the length of the columns in the dataset
column_length = len(sales.columns)
print(f"The length of the columns in the dataset: {column_length}")
# Out:
# The length of the columns in the dataset: 11

# %%
# Displaying a specific location using loc (label)
find_location = sales.loc['Albania']
find_location
# Out:
#                                    customer_id  \
# location
# Albania   2cef58cc-d9d5-4000-9ae0-51244945a1e8
# Albania   2cef58cc-d9d5-4000-9ae0-51244945a1e8
# Albania   2cef58cc-d9d5-4000-9ae0-51244945a1e8
# Albania   2cef58cc-d9d5-4000-9ae0-51244945a1e8
# Albania   2cef58cc-d9d5-4000-9ae0-51244945a1e8
# ...                                        ...
# Albania   701e551b-a127-4969-a9d9-82abd2031590
# Albania   701e551b-a127-4969-a9d9-82abd2031590
# Albania   701e551b-a127-4969-a9d9-82abd2031590
# Albania   701e551b-a127-4969-a9d9-82abd2031590
# Albania   701e551b-a127-4969-a9d9-82abd2031590
#
#                                      device_id  item_id  line_item_id  \
# location
# Albania   899b69ce-8c3f-403f-ab2a-63ab10aaab46        7          5180
# Albania   899b69ce-8c3f-403f-ab2a-63ab10aaab46        5          5181
# Albania   899b69ce-8c3f-403f-ab2a-63ab10aaab46       13          5182
# Albania   899b69ce-8c3f-403f-ab2a-63ab10aaab46       15          5183
# ...

# %%
# Displaying locations using the iloc(index)
find_location_index = sales.iloc[4000:]
find_location_index
# Out:
#                                            customer_id  \
# location
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Poland            4ae11055-6894-4298-b258-9b57deee8962       12          3416
# Poland            4ae11055-6894-4298-b258-9b57deee8962       10          3417
# ...

# %% [markdown]
# ## **Filtering the sales data using their customer_id** ##

# %%
# setting the customer_id to 1
id_customer = sales[sales['customer_id'] == "0b1d359b-6e85-4f42-86bb-3e3675e4bf47"]
id_customer
# Out:
#                                    customer_id  \
# location
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# ...                                        ...
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
#
#                                      device_id  item_id  line_item_id  \
# location
# Poland    4ae11055-6894-4298-b258-9b57deee8962       12          3416
# Poland    4ae11055-6894-4298-b258-9b57deee8962       10          3417
# Poland    4ae11055-6894-4298-b258-9b57deee8962        1          3418
# Poland    4ae11055-6894-4298-b258-9b57deee8962        2          3419
# ...

# %%
# Changing the date format to date time
dates = sales['event_timestamp']
dates = pd.to_datetime(dates)
dates
# Out:
# location
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
#                               ...
# Christmas Island   2024-03-30 04:03:18.224196
# Christmas Island   2024-03-30 04:03:18.224198
# Christmas Island   2024-03-30 04:03:18.224198
# Christmas Island   2024-03-30 04:14:18.224200
# Christmas Island   2024-03-30 04:14:18.224200
# Name: event_timestamp, Length: 578320, dtype: datetime64[ns]

# %%
# Total number of customers
no_of_customers = sales['customer_id'].nunique()
print(f"The total number of unique customers: {no_of_customers}")
# Out:
# The total number of unique customers: 4594

# %% [markdown]
# `Data visualization of top twenty five customers using barchart pandas`

# %%
# Sorting the top 25 customers with the highest purchases
top_25_customers = sales['customer_id'].value_counts().head(25).sort_values(ascending=False).plot(kind='bar',ylabel='Purchases', title='The Top 25 Customers')
print(f"Below are the top twenty five customers with the highest purchases\n{top_25_customers}")
# Out:
# Below are the top twenty five customers with the highest purchases
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## **Masking** ##

# %%
# Checking customer behaviour
mask = (sales['customer_id'] == "ef15a7b3-326c-405f-9eef-3dbf43c85a9d")
customer_behaviour = sales[mask].head(5)
customer_behaviour
# Out:
#                                            customer_id  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
#
#                                               order_id  event_id  \
# location
# ...

# %%
# Checking the customer behaviour using loc 
sales.loc[mask].head(5)
# Out:
#                                            customer_id  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
#
#                                               order_id  event_id  \
# location
# ...

# %%
# Masking the customer_id against the currency
sales.loc[mask, 'customer_id':'currency'].head(2)
# Out:
#                                            customer_id  \
# location
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# Christmas Island  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
#
#                                               order_id  event_id  \
# location
# Christmas Island  ad73a2a0-354a-40bf-81cd-ff017ac859d5    161951
# Christmas Island  ad73a2a0-354a-40bf-81cd-ff017ac859d5    161951
#
#                              event_timestamp  quantity currency
# location
# Christmas Island  2024-03-26 11:21:06.639379         3      USD
# Christmas Island  2024-03-26 11:21:06.639379         3      USD

# %% [markdown]
# ## **Currency** ##

# %%
# Checking the unique currencies in the dataset
currencies = sales['currency'].unique()
no_currencies = sales['currency'].nunique()
print(f"The dataset has a total number of {no_currencies} unique currencies which are {currencies}")
# Out:
# The dataset has a total number of 3 unique currencies which are ['NGN' 'USD' 'GBP']

# %%
# Number of times the currencies were used 
currency_usage = sales['currency'].value_counts()
print(f"Total number of times the {currencies} were used:\n{currency_usage}")
# Out:
# Total number of times the ['NGN' 'USD' 'GBP'] were used:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of the currencies used for purchase using pie chart in  Pandas`

# %%
# Plotting a bar chart to show the number of times a currency was used
currency_usage.plot(kind='pie', title='Currencies Used(USD, GBP, NGN)')
# Out:
# <Axes: title={'center': 'Currencies Used(USD, GBP, NGN)'}, ylabel='count'>

# %% [markdown]
# ## **Applying Multiple Filters** ##

# %%
# Using a particular customer_info for masking
mask = (sales['customer_id'] == "0b1d359b-6e85-4f42-86bb-3e3675e4bf47")
mask
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Name: customer_id, Length: 578320, dtype: bool

# %%
# Selecting a customer with a successful transaction
mask2 = (sales['customer_id'] == "0b1d359b-6e85-4f42-86bb-3e3675e4bf47") & (sales['status'] == 'success')
mask2
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Length: 578320, dtype: bool

# %%
# Checking the index of the customer with successful transactions
sucsess_customerA = sales.loc[mask2]
sucsess_customerA
# Out:
#                                    customer_id  \
# location
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# ...                                        ...
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland    0b1d359b-6e85-4f42-86bb-3e3675e4bf47
#
#                                      device_id  item_id  line_item_id  \
# location
# Poland    4ae11055-6894-4298-b258-9b57deee8962       12          3416
# Poland    4ae11055-6894-4298-b258-9b57deee8962       10          3417
# Poland    4ae11055-6894-4298-b258-9b57deee8962        1          3418
# Poland    4ae11055-6894-4298-b258-9b57deee8962        2          3419
# ...

# %%
# Checking the number of successful transactions by the sample customer selected
sucsess_customerA = sales.loc[mask2]
no_of_purchase = sucsess_customerA['status'].value_counts
print(f"The list of successful transactions carried out by customer A is {no_of_purchase}")
# Out:
# The list of successful transactions carried out by customer A is <bound method IndexOpsMixin.value_counts of location
# Poland    success
# Poland    success
# Poland    success
# Poland    success
# Poland    success
#            ...
# Poland    success
# Poland    success
# Poland    success
# Poland    success
# Poland    success
# Name: status, Length: 105, dtype: object>

# %%
# Filter based on failed transactions
mask3 = (sales['status'] == 'failed')
mask3
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Name: status, Length: 578320, dtype: bool

# %%
# Checking the failed transactions in the dataset
failed_customerA = sales.loc[mask3]
failed_customerA
# Out:
#                                            customer_id  \
# location
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali              f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# ...

# %%
# Transaction History Count
transaction_status = sales['status'].value_counts()
print(f"Below is the transaction history {transaction_status}")
# Out:
# Below is the transaction history status
# failed       196383
# success      192594
# cancelled    189343
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of the transactions using barchart in  Pandas`

# %%
# Plotting a chart of the transaction history showing all statuses
transaction_status.plot(kind='bar',ylabel= 'Frequency', title='Transaction History', color='brown')
# Out:
# <Axes: title={'center': 'Transaction History'}, xlabel='status', ylabel='Frequency'>

# %%
# Checking the effects of the status of the transaction against the currency
status_by_currency = sales.groupby("currency")["status"].value_counts()
print(status_by_currency)
# Out:
# currency  status
# GBP       cancelled    64324
#           success      64266
#           failed       62813
# NGN       success      66146
#           failed       65387
#           cancelled    57347
# USD       failed       68183
#           cancelled    67672
#           success      62182
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of the transactions using barchart in Pandas`

# %%
import seaborn
# Plotting a bar chart for the currency against the status using seaborn
status_by_currency = sales.groupby("currency")["status"].sum().sort_values(ascending=True)
sns.lineplot(x=status_by_currency.index, y=status_by_currency.values)
# plt.xlabel('Status')
# plt.ylabel('Currency')
# plt.title('Status by Currency')
# plt.xticks(rotation = 90)
# plt.show
# Out:
# <Axes: xlabel='currency'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ncc84\Desktop\module2_tasks\Module_2_task_submissions\venv\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\ncc84\Desktop\module2_tasks\Module_2_task_submissions\venv\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...

# %%
# Using a specified location for the analysis
Vietnam = sales.loc['Vietnam']
Vietnam.head(4)
# Out:
#                                    customer_id  \
# location
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       14          4249
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       13          4250
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        1          4251
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        8          4252
#
#                                       order_id  event_id  \
# location
# Vietnam   7434fc42-7600-424e-8498-148d2e1e860b     19670
# Vietnam   7434fc42-7600-424e-8498-148d2e1e860b     19670
# Vietnam   7434fc42-7600-424e-8498-148d2e1e860b     19670
# Vietnam   7434fc42-7600-424e-8498-148d2e1e860b     19670
#
# ...

# %%
# Getting the information about the location
Vietnam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2061 entries, Vietnam to Vietnam
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2061 non-null   object
#  1   device_id        2061 non-null   object
#  2   item_id          2061 non-null   int64
#  3   line_item_id     2061 non-null   int64
#  4   order_id         2061 non-null   object
#  5   event_id         2061 non-null   int64
#  6   event_timestamp  2061 non-null   object
#  7   quantity         2061 non-null   int64
#  8   currency         2061 non-null   object
#  9   checked_out_at   2061 non-null   object
#  10  status           2061 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 193.2+ KB

# %%
# Checking the size of the data
size = Vietnam.shape
print(f"The size of the data for vietnam: {size}")
# Out:
# The size of the data for vietnam: (2061, 11)

# %%
# Checking the status of transactions in Vietnam
failed_trans = Vietnam[Vietnam['status'] == "failed"]
successful_trans = Vietnam[Vietnam['status'] == "success"]
cancelled_trans = Vietnam[Vietnam['status'] == "cancelled"]

# %%
# Checking the number of failed transactions
size_failed = failed_trans.shape[0]
print(f"The size of failed transactions in Vietnam: {size_failed}")
# Out:
# The size of failed transactions in Vietnam: 642

# %%
# Checking the number of cancelled transactions
size_cancelled = cancelled_trans.shape[0]
print(f"The size of cancelled transactions in Vietnam: {size_cancelled}")
# Out:
# The size of cancelled transactions in Vietnam: 503

# %%
# Checking the number of cancelled transactions
size_successful = successful_trans.shape[0]
print(f"The size of successful transactions in Vietnam: {size_successful}")
# Out:
# The size of successful transactions in Vietnam: 916

# %%
# Number Customers that had failed transactions 
no_failed_trans = failed_trans.customer_id.nunique()
failed_trans
# Out:
#                                    customer_id  \
# location
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# ...                                        ...
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       14          4249
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       13          4250
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        1          4251
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        8          4252
# ...

# %%
# Customers that had failed transactions
id_failed_trans = failed_trans.customer_id.unique()
id_failed_trans
# Out:
# array(['ccacbe4d-535b-4e77-bbb7-5ba7c203bd41',
#        'a74b2b8b-55b8-4267-a439-eaa5d14d25dd',
#        '4e8fb00f-467b-4159-9636-f8623357cbca',
#        '13561063-0cf7-4616-b3d0-035cb95796a2'], dtype=object)

# %%
# Selecting the id of the first failed transaction to understand the cause
ccacbe4d = failed_trans[failed_trans['customer_id'] == "ccacbe4d-535b-4e77-bbb7-5ba7c203bd41"]
ccacbe4d.head(1)
# Out:
#                                    customer_id  \
# location
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       14          4249
#
#                                       order_id  event_id  \
# location
# Vietnam   7434fc42-7600-424e-8498-148d2e1e860b     19670
#
#                      event_timestamp  quantity currency  \
# location
# Vietnam   2024-03-30 04:03:10.711983         3      GBP
#
#                       checked_out_at  status
# location
# Vietnam   2024-03-30 04:11:10.712062  failed

# %%
# The number of times the first customer experienced a failed transaction
ccacbe4d.shape[0]
print(f"The customer experienced a total number of 276 failed transactions{ccacbe4d}")
# Out:
# The customer experienced a total number of 276 failed transactions                                   customer_id  \
# location
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# ...                                        ...
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       14          4249
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       13          4250
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        1          4251
# ...

# %%
# What currency was the first customer using for the transaction
type_currency = ccacbe4d.currency.unique()
print(f"This customer was trying to pay in {type_currency}")
# Out:
# This customer was trying to pay in ['GBP']

# %%
# Selecting the id of the second failed transaction to understand the cause
a74b2b8b= failed_trans[failed_trans['customer_id'] == "a74b2b8b-55b8-4267-a439-eaa5d14d25dd"]
a74b2b8b.head(1)
# Out:
#                                    customer_id  \
# location
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   75e126e8-869c-4a76-801e-60fc73e9068f       10          5936
#
#                                       order_id  event_id  \
# location
# Vietnam   331b84cc-5ab1-4bf6-aa7d-17978fff1640     27310
#
#                      event_timestamp  quantity currency  \
# location
# Vietnam   2024-03-22 21:51:32.158047         5      USD
#
#                       checked_out_at  status
# location
# Vietnam   2024-03-30 04:16:11.106577  failed

# %%
# The number of times the second customer experienced a failed transaction
a74b2b8b.shape[0]
print(f"The customer experinced a total number of 250 failed transactions{a74b2b8b}")
# Out:
# The customer experinced a total number of 250 failed transactions                                   customer_id  \
# location
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# ...                                        ...
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
# Vietnam   a74b2b8b-55b8-4267-a439-eaa5d14d25dd
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   75e126e8-869c-4a76-801e-60fc73e9068f       10          5936
# Vietnam   75e126e8-869c-4a76-801e-60fc73e9068f        2          5937
# Vietnam   75e126e8-869c-4a76-801e-60fc73e9068f       14          5938
# ...

# %%
# What currency was the second customer using for the transaction
type_currency = a74b2b8b.currency.unique()
print(f"This customer was trying to pay in {type_currency}")
# Out:
# This customer was trying to pay in ['USD']

# %%
# Selecting the id of the third failed transaction to understand the cause
fb00f = failed_trans[failed_trans['customer_id'] == "4e8fb00f-467b-4159-9636-f8623357cbca"]
fb00f.head(1)
# Out:
#                                    customer_id  \
# location
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   410210f8-f83b-4e7f-9317-144996a52e44       14         18148
#
#                                       order_id  event_id  \
# location
# Vietnam   ab52e367-f6d4-484f-b5dc-dd973b7e4571     84185
#
#                      event_timestamp  quantity currency  \
# location
# Vietnam   2024-03-30 04:03:14.112565         1      NGN
#
#                       checked_out_at  status
# location
# Vietnam   2024-03-30 04:15:14.112625  failed

# %%
# The number of times the third customer experienced a failed transaction
fb00f.shape[0]
print(f"The customer experinced a total number of XXX failed transactions{fb00f}")
# Out:
# The customer experinced a total number of XXX failed transactions                                   customer_id  \
# location
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# Vietnam   4e8fb00f-467b-4159-9636-f8623357cbca
# ...

# %%
# What currency was the third customer using for the transaction
type_currency = fb00f.currency.unique()
print(f"This customer was trying to pay in {type_currency}")
# Out:
# This customer was trying to pay in ['NGN']

# %%
# Selecting the id of the fourth failed transaction to understand the cause
b3d0 = failed_trans[failed_trans['customer_id'] == "13561063-0cf7-4616-b3d0-035cb95796a2"]
b3d0.head(1)
# Out:
#                                    customer_id  \
# location
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   b754b2f3-9fa4-4365-b6de-131fb65f4f50       13         29634
#
#                                       order_id  event_id  \
# location
# Vietnam   4d2338ac-3f0f-4609-a00a-80767d2fe0da    137055
#
#                      event_timestamp  quantity currency  \
# location
# Vietnam   2024-03-21 07:43:55.778344         4      NGN
#
#                       checked_out_at  status
# location
# Vietnam   2024-03-30 04:19:16.852751  failed

# %%
# The number of times the fourth customer experienced a failed transaction
b3d0.shape[0]
print(f"The customer experinced a total number of XXX failed transactions{b3d0}")
# Out:
# The customer experinced a total number of XXX failed transactions                                   customer_id  \
# location
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# Vietnam   13561063-0cf7-4616-b3d0-035cb95796a2
# ...

# %%
# What currency was the fourth customer using for the transaction
type_currency = b3d0.currency.unique()
print(f"This customer was trying to pay in {type_currency}")
# Out:
# This customer was trying to pay in ['NGN']

# %%
# Checking the if any of the four customers ever had a successful transaction
trans_successful = successful_trans[successful_trans['customer_id'] == "ccacbe4d-535b-4e77-bbb7-5ba7c203bd41"] 
trans_successful.shape # Customer never had a successful transaction.
# Out:
# (0, 11)

# %%
# Checking the timestamp to understand why
timestamp_check = ccacbe4d['event_timestamp'].value_counts() # All failed transactions happened in less than a minute. 
timestamp_check
# Out:
# event_timestamp
# 2024-03-30 04:03:10.712034    24
# 2024-03-30 04:03:10.711983    12
# 2024-03-30 04:03:10.712031    12
# 2024-03-30 04:03:10.712036    12
# 2024-03-30 04:03:10.712037    12
# 2024-03-30 04:03:10.712039    12
# 2024-03-30 04:03:10.712040    12
# 2024-03-30 04:03:10.712041    12
# 2024-03-30 04:03:10.712043    12
# 2024-03-30 04:03:10.712045    12
# 2024-03-30 04:03:10.712046    12
# 2024-03-30 04:03:10.712047    12
# 2024-03-30 04:03:10.712048    12
# 2024-03-30 04:03:10.712050    12
# 2024-03-30 04:03:10.712051    12
# 2024-03-30 04:03:10.712052    12
# 2024-03-30 04:03:10.712054    12
# 2024-03-30 04:03:10.712055    12
# 2024-03-30 04:03:10.712056    12
# 2024-03-30 04:03:10.712057    12
# 2024-03-30 04:03:10.712059    12
# 2024-03-30 04:11:10.712062    12
# Name: count, dtype: int64

# %%
# Checking the quantity of the order placed
quantity_ordered = ccacbe4d['quantity'].value_counts()
quantity_ordered
# Out:
# quantity
# 3    115
# 4     69
# 5     46
# 1     23
# 2     23
# Name: count, dtype: int64

# %%
# Checking the quantity of the order placed
quantity_check = ccacbe4d['quantity'].sort_values(ascending=False)
quantity_check
# Out:
# location
# Vietnam    5
# Vietnam    5
# Vietnam    5
# Vietnam    5
# Vietnam    5
#           ..
# Vietnam    1
# Vietnam    1
# Vietnam    1
# Vietnam    1
# Vietnam    1
# Name: quantity, Length: 276, dtype: int64

# %%
# Checking the order id 
order_check = ccacbe4d['order_id'].value_counts()
print(f"The Order id is\n{order_check}; for all the transactions") #The order_id is the same for all the orders
# Out:
# The Order id is
# order_id
# 7434fc42-7600-424e-8498-148d2e1e860b    276
# Name: count, dtype: int64; for all the transactions

# %%
# Checking the type of item ordered 
item_check = ccacbe4d['item_id'].unique()
print(f"The customeer tried to order all these items\n{item_check}")
# Out:
# The customeer tried to order all these items
# [14 13  1  8  9  5 12  3  2 15 10 11]

# %%
# Checking the the number of the item ordered 
item_no_check = ccacbe4d['item_id'].value_counts()
print(f"The customer tried to order each item 23 times\n{item_no_check}")
# Out:
# The customer tried to order each item 23 times
# item_id
# 14    23
# 13    23
# 1     23
# 8     23
# 9     23
# 5     23
# 12    23
# 3     23
# 2     23
# 15    23
# 10    23
# 11    23
# Name: count, dtype: int64

# %%
# Checking the number of times the customer tried to place the order
event_no_check = ccacbe4d['event_id'].nunique()
print(f"The customer tried to order each item {event_no_check} times")
# Out:
# The customer tried to order each item 23 times

# %%
# Checking the how the event unfolded
event_check = ccacbe4d['event_id'].value_counts()
event_check
# Out:
# event_id
# 19670    12
# 19671    12
# 19672    12
# 19673    12
# 19674    12
# 19675    12
# 19676    12
# 19677    12
# 19678    12
# 19679    12
# 19680    12
# 19681    12
# 19682    12
# 19683    12
# 19684    12
# 19685    12
# 19686    12
# 19687    12
# 19688    12
# 19689    12
# 19690    12
# 19691    12
# 19692    12
# Name: count, dtype: int64

# %%
# Checking for duplicate order
no_duplicate_order = ccacbe4d['event_id'].duplicated().sum()
print(f"The customer has {no_duplicate_order} duplicated orders")
# Out:
# The customer has 253 duplicated orders
